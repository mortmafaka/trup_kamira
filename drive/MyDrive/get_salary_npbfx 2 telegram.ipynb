# %%
import requests
import json
import time

def get_bearer_token(email, password):
    url = 'https://my.npbfx-ru.org/oauth/token'
    headers = {
        'Authorization': 'Basic cGVyc29uYWxBcHA6SDM5eTgmRCpCZk1QcWM=',
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    data = {
        'username': email,
        'password': password,
        'grant_type': 'password'
    }
    response = requests.post(url, headers=headers, data=data)
    if response.status_code == 200:
        return json.loads(response.text)['access_token']
    else:
        print("Ошибка получения токена: ", response.status_code)
        return None

# Теперь используйте эту функцию для получения токена
email = 'mortmafaka@gmail.com'
password = 'MJQUfiWy'
bearer_token = get_bearer_token(email, password)

# И используйте полученный токен в вашем основном коде




def get_records(email, password):
    bearer_token = get_bearer_token(email, password)
    if bearer_token is None:
        print("Не удалось получить Bearer токен")
        return None

    url = 'https://my.npbfx-ru.org/mobile/billing/rest/payments/list'

    headers = {
        'accept': '*/*',
        'accept-language': 'ru,en;q=0.9',
        'referer': 'https://my.npbfx-ru.org/billing/history',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 YaBrowser/23.3.0.2246 Yowser/2.5 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest',
        'Authorization': f'Bearer {bearer_token}'
    }

    response = requests.get(url, headers=headers)
    data = json.loads(response.text)
    return data

def send_telegram_notification(chat_id, message):
    bot_token = '6219227192:AAElbTKggpPygwh8KSSsKPWD3aNFXirp4oM'
    url = f'https://api.telegram.org/bot{bot_token}/sendMessage'
    payload = {'chat_id': chat_id, 'text': message}
    response = requests.post(url, data=payload)

    if response.status_code == 200:
        print("Уведомление успешно отправлено.")
    else:
        print(f"Ошибка при отправке уведомления: {response.status_code}")

last_records = get_records(email, password)
chat_id = '197381682'  # Замените 'your_telegram_chat_id' на ID чата, в который вы хотите получать уведомления

while True:
    time.sleep(60)
    new_records = get_records(email, password)
    new_records_found = False

    for new_record in new_records['obj']['list']:
        if new_record not in last_records['obj']['list']:
            message = f"Новая запись: {new_record}"
            print(message)
            send_telegram_notification(chat_id, message)
            new_records_found = True

    if not new_records_found:
        print("Изменений нет.")

    last_records = new_records
# Out:
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# Изменений нет.
# ...

# %%
import requests
import json

def send_telegram_notification(chat_id, message):
    bot_token = '6219227192:AAElbTKggpPygwh8KSSsKPWD3aNFXirp4oM'
    url = f'https://api.telegram.org/bot{bot_token}/sendMessage'
    payload = {'chat_id': chat_id, 'text': message}
    response = requests.post(url, data=payload)

    if response.status_code == 200:
        print("Уведомление успешно отправлено.")
    else:
        print(f"Ошибка при отправке уведомления: {response.status_code}")

chat_id = '197381682'  # Замените 'your_telegram_chat_id' на ID чата, в который вы хотите получать уведомления
message = 'Тестовое сообщение'
send_telegram_notification(chat_id, message)
