# %%
pip install pyppeteer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 906.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
# ...

# %%
import asyncio
from pyppeteer import launch

async def main():
    browser = await launch(
        headless=False,
        args=[
            '--user-data-dir=Market_Parser',
            '--user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 Safari/537.36',
            '--disable-dev-shm-usage',
            '--v=99',
            '--no-sandbox'
        ]
    )

    page = await browser.newPage()
    await page.goto('https://market.yandex.ru/catalog--noutbuki/26895412/list?srnum=2574&was_redir=1&rt=9&rs=eJwz2socwFjFwtF6nHUWo-yFvRf2XWy-2HRh48XmC7sULuy4sPliw4V9FzYB8c5VjFwc-14eERS4daaX6ygjw4MZtkByAa8diHy4B0gyfNoLJBtmg0iGiyBZh782IFlXkKyC5m6QeChI_YFdIPEHQSDxA4Eg8sFHK5DKg2BdxyxB4mtA7ARukEoGIZCZCY0gcoE2SFxBGKSrYSfYRnOwS46DyIazIPLATpBpCdPALqkFiwTvB7HPgs2ZAzZBCcR2MASZs-AE2K6VILsSFoH9YgDWZQ82swSs3hBsyyQQ-SAFTLaB_dUNdvMakGkPmMC6wsCuagX77hjYNFWwOVGgEFhgBhYx2gfSNXknyIQpYBE-sO0MILJhN9g0I7ALv4NFikHsA7qg0FP4tRcAZDyorQ%2C%2C&suggest=1&suggest_type=search&text=ноутбук%20игровой&hid=91013&allowCollapsing=1&local-offers-first=0')

    # Извлекаем контент из селектора и сохраняем в список
    content_selector = "[id^='page-'] > div > div > div > div > div:nth-child(1) > div > div > div > div > div > div > div > div > div > div > ul"
    content_element = await page.querySelector(content_selector)
    text_content = await content_element.getProperty('textContent')
    content = await text_content.jsonValue()
    content_list = [content]
    print(content_list)
    # Кликаем по кнопке
    button_selector = 'div[data-baobab-name="scrollRight"] > button'

    await page.click(button_selector)

    await browser.close()

asyncio.get_event_loop().run_until_complete(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-c5d58de709e5> in <cell line: 33>()
#      31     await browser.close()
#      32
# ---> 33 asyncio.get_event_loop().run_until_complete(main())
#      34
#
# /usr/lib/python3.10/asyncio/base_events.py in run_until_complete(self, future)
#     623         """
#     624         self._check_closed()
# --> 625         self._check_running()
#     626
#     627         new_task = not futures.isfuture(future)
#
# /usr/lib/python3.10/asyncio/base_events.py in _check_running(self)
#     582     def _check_running(self):
#     583         if self.is_running():
# --> 584             raise RuntimeError('This event loop is already running')
#     585         if events._get_running_loop() is not None:
#     586             raise RuntimeError(
#
# RuntimeError: This event loop is already running
