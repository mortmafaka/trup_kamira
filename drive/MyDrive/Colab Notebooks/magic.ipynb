# %%
# !pip install langchain
# !pip install pypdf
# !pip install sentence-transformers
# !pip install openai
# !pip install chromadb
# !pip install tiktoken
# !pip install unstructured
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 36.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 49.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 59.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 15.5 MB/s eta 0:00:00
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184491 sha256=3b351061aac452233095c51bc4ccbabb572e9cc3c4ae15457bdef85bf7a4c2b5
# ...

# %%
from langchain.document_loaders import UnstructuredPDFLoader
import re



# Function to clean text and print up to a specified length
def clean_and_print_text(text, max_length=100):
    # Clean the text
    cleaned_text = clean_text(text)

    # Print the cleaned text, up to a specified length
    if len(cleaned_text) > max_length:
        cleaned_text = cleaned_text[:max_length] + "..."
    print(cleaned_text)

# Function to clean text from unnecessary characters
def clean_text(text):
    # Remove unwanted characters
    cleaned_text = re.sub(r'[^\w\s]', '', text)

    # Remove extra whitespaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)

    return cleaned_text.strip()

# Load and split PDF pages
loader = UnstructuredPDFLoader(
'/content/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf', mode="single", strategy="fast",

)
docs = loader.load()


# Iterate over pages, clean text, and print
for page in docs:
    # Get the page content
    page_content = page.page_content

    # Clean and print the text
    clean_and_print_text(page_content)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Райан Митчелл Современный скрапинг вебсайтов с помощью Python 2е межд издание 2021 Научный редактор ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Define your text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,  # Set the size of the chunks
    chunk_overlap=150  # Set the size of the overlap between chunks
)

# Use the text splitter to split your documents' text into chunks
split_docs = []
for doc in cleaned_docs:
    split_texts = text_splitter.split_text(doc)
    split_docs.extend([Document(page_content=text) for text in split_texts])

# Create a Chroma vector store using the OpenAIEmbeddings and the list of split documents
vectorstore = Chroma.from_documents(split_docs, embeddings)
# Out:
# Собирать информацию из Интернета словно пить из пожарного шланга Ее слишком много и не всегда понятно что именно вам нужно и как это получить Ответ на эти вопросы должен стать первым шагом в любом крупном а иногда и небольшом вебпроекте При сборе одних и тех же данных в разных областях или из разных источников ваша цель почти всегда должна состоять в том чтобы попытаться нормализовать эти данные Работать с данными имеющими одинаковые или сопоставимые поля гораздо проще чем с данными формат которых полностью определяется их первоначальным источником Во многих случаях приходится создавать вебскраперы исходя из вероятного появления новых источников данных в дальнейшем и с целью минимизировать издержки на программирование которые потребуются для добавления этих новых источников Даже если на первый взгляд сайт не соотносится с вашей моделью возможно есть более тонкие способы обеспечить данное соответствие В долгосрочной перспективе умение замечать эти базовые закономерности позволит вам с
# ...

# %%
persist_directory = 'docs/chroma/'
embedding = OpenAIEmbeddings()
vectordb = Chroma(
    persist_directory=persist_directory,
    embedding_function=embedding
)

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
embedding = OpenAIEmbeddings()

# %%
# Perform similarity search
query = "Twitter"
results = vectorstore.similarity_search(query)

# Check if results were found
if results:
    # Print the page content of the most similar document
    print(results[1].page_content)
else:
    print("No similar documents found.")
# Out:
# 3граммы Другой подход заключается в поиске предложений содержащих самые популярные nграммы Конечно это будут более длинные предложения и в случае возникновения проблем можно поискать предложения с наибольшим процентом слов которые являются популярными nграммами или создать собственную метрику оценки комбинируя несколько приемов Модели Маркова Возможно вам приходилось слышать о текстовых генераторах Маркова Они стали популярными в развлекательных приложениях таких как сайт That can be my next tweet Это мог твит мой httpyesthatcanbemynexttweet а также применяются для создания спамписем которые выглядят как настоящие и призваны обмануть системы обнаружения спама бы быть следующий Все эти текстовые генераторы основаны на модели Маркова которая часто используется для анализа больших множеств случайных событий где каждое дискретное событие может сопровождаться другим дискретным событием с определенной вероятностью Например можно построить модель Маркова для системы прогноза погоды как пока
# ...

# %%
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
import re
import openai
import os

# Function to clean text from unnecessary characters
def clean_text(text):
    # Remove unwanted characters
    cleaned_text = re.sub(r'[^\w\s]', '', text)

    # Remove extra whitespaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)

    return cleaned_text.strip()

# Load and split PDF pages
loader = UnstructuredPDFLoader(
    '/content/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf', mode="single", strategy="fast",
)
raw_docs = loader.load()

# Clean documents and store them
cleaned_docs = [clean_text(doc.page_content) for doc in raw_docs]

# Define the Document class
class Document:
    def __init__(self, page_content, metadata=None):
        self.page_content = page_content
        self.metadata = metadata

# Setup OpenAI API key
openai.api_key = "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"
os.environ["OPENAI_API_KEY"] = "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"

# Initialize OpenAIEmbeddings with the API key
embeddings = OpenAIEmbeddings(openai_api_key="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")

# Create a list of document objects
documents = [Document(page_content=text) for text in cleaned_docs]

# Create a Chroma vector store using the OpenAIEmbeddings and the list of documents
vectorstore = Chroma.from_documents(documents, embeddings)

# Perform similarity search
query = "как подклоючиться к twitter api"
results = vectorstore.similarity_search(query)

# Check if results were found
if results:
    # Print the page content of the most similar document
    print(results[0].page_content)
else:
    print("No similar documents found.")
# Out:
# WARNING:langchain.embeddings.openai:Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIError: The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID 9e5caea394e78311ac73068c4741a832 in your email.) {
#   "error": {
#     "message": "The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID 9e5caea394e78311ac73068c4741a832 in your email.)",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# }
# ...

# %%
# from langchain.document_loaders import PyPDFLoader
# import re

# # Function to clean text and print up to a specified length
# def clean_and_print_text(text, max_length=100):
#     # Clean the text
#     cleaned_text = clean_text(text)

#     # Print the cleaned text, up to a specified length
#     if len(cleaned_text) > max_length:
#         cleaned_text = cleaned_text[:max_length] + "..."
#     print(cleaned_text)

# # Function to clean text from unnecessary characters
# def clean_text(text):
#     # Remove unwanted characters
#     cleaned_text = re.sub(r'[^\w\s]', '', text)

#     # Remove extra whitespaces
#     cleaned_text = re.sub(r'\s+', ' ', cleaned_text)

#     return cleaned_text.strip()

# # Load and split PDF pages
# loader = PyPDFLoader("/content/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf")
# pages = loader.load_and_split()

# # Iterate over pages, clean text, and print
# for page in pages:
#     # Get the page content
#     page_content = page.page_content

#     # Clean and print the text
#     clean_and_print_text(page_content)

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
import re
import openai
import os
with open("/content/cleaned_texts.txt", "r") as file:
    cleaned_texts = file.read()

# Print the file contents
openai.api_key = "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"
os.environ["OPENAI_API_KEY"] = "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"

# Define the Document class
class Document:
    def __init__(self, page_content, metadata=None):
        self.page_content = page_content
        self.metadata = metadata

# Initialize OpenAIEmbeddings with the API key
embeddings = OpenAIEmbeddings(openai_api_key="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")

# Create a list of document objects
documents = [Document(page_content=text) for text in cleaned_texts]

# Create a Chroma vector store using the OpenAIEmbeddings and the list of documents
vectorstore = Chroma.from_documents(documents, embeddings)

# Perform similarity search
query = "What did the president say about Ketanji Brown Jackson"
results = vectorstore.similarity_search(query)

# Print the page content of the most similar document
print(results[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-42de16a2cd33> in <cell line: 34>()
#      32
#      33 # Print the page content of the most similar document
# ---> 34 print(results[0].page_content)
#
# IndexError: list index out of range

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
import re
import openai
OPENAI_API_KEY="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"


openai.api_key  = OPENAI_API_KEY
# Function to clean text and return cleaned text
def clean_text(text):
    # Remove unwanted characters
    cleaned_text = re.sub(r'[^\w\s]', '', text)

    # Remove extra whitespaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)

    return cleaned_text.strip()

# Load and split PDF pages
loader = PyPDFLoader("/content/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf")
pages = loader.load_and_split()

# Create a list to store cleaned text
cleaned_texts = []

# Iterate over pages, clean text, and append to the list
for page in pages:
    # Get the page content
    page_content = page.page_content

    # Clean the text
    cleaned_text = clean_text(page_content)

    # Append cleaned text to the list
    cleaned_texts.append(cleaned_text)

# Save the cleaned texts to a file
# Save the cleaned texts to a file
with open("cleaned_texts.txt", "w") as f:
    for text in cleaned_texts:
        f.write(text + "\n")

# %%
with open('/content/cleaned_texts.txt', 'r') as f:
    contents = f.read()
    print(contents)

# %%
from getpass import getpass
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
import os

OPENAI_API_KEY = getpass("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")

# Set the API key as an environment variable
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# Initialize OpenAIEmbeddings
embeddings = OpenAIEmbeddings()

# Create a Chroma vector store using the OpenAIEmbeddings
vectorstore = Chroma.from_documents(docs, embeddings)

# Perform similarity search
query = "What did the president say about Ketanji Brown Jackson"
results = vectorstore.similarity_search(query)

# Print the page content of the most similar document
print(results[0].page_content)

# %%
with open('/content/cleaned_texts.txt', 'r') as r:
    for text in cleaned_texts:
      print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9a96d44718c0> in <cell line: 1>()
#       1 with open('/content/cleaned_texts.txt', 'r') as r:
# ----> 2     for text in cleaned_texts:
#       3       print(text)
#
# NameError: name 'cleaned_texts' is not defined

# %%
# Save the cleaned texts to a file
with open("cleaned_texts.txt", "w") as f:
    for text in cleaned_texts:
        f.write(text + "\n")

# Create the vector store
embeddings_model = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
vectorstore = Chroma.from_documents(documents=cleaned_texts, embedding=embeddings_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3758fe4d774a> in <cell line: 2>()
#       1 # Save the cleaned texts to a file
#       2 with open("cleaned_texts.txt", "w") as f:
# ----> 3     for text in cleaned_texts:
#       4         f.write(text + "\n")
#       5
#
# NameError: name 'cleaned_texts' is not defined

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings

# Set your OpenAI API key
openai_api_key = OPENAI_API_KEY

# Initialize the OpenAI embeddings model
embeddings_model = OpenAIEmbeddings(openai_api_key=openai_api_key)

# Embed the documents
embeddings = embeddings_model.embed_documents(documents)

# Create the vector store
vectorstore = Chroma.from_documents(documents, embeddings)

# Access the embeddings and vectorstore as needed
# For example, to get the embeddings of the first document:
first_document_embeddings = embeddings[0]

# To perform vector similarity search in the vector store:
similar_documents = vectorstore.most_similar(vector=first_document_embeddings, top_k=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d6f6ae1c1c7b> in <cell line: 11>()
#       9
#      10 # Embed the documents
# ---> 11 embeddings = embeddings_model.embed_documents(documents)
#      12
#      13 # Create the vector store
#
# NameError: name 'documents' is not defined

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
import re
import openai

OPENAI_API_KEY = "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"
openai.api_key = OPENAI_API_KEY

# Function to clean text and return cleaned text
def clean_text(text):
    cleaned_text = re.sub(r'[^\w\s]', '', text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    return cleaned_text.strip()

# Load and split PDF pages
loader = PyPDFLoader("/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf")
pages = loader.load_and_split()

# Create a list to store cleaned text
cleaned_texts = []

# Iterate over pages, clean text, and append to the list
for page in pages:
    # Get the page content
    page_content = page.page_content

    # Clean the text
    cleaned_text = clean_text(page_content)

    # Append cleaned text to the list
    cleaned_texts.append(cleaned_text)

# Save the cleaned texts to a file
with open('/content/cleaned_texts.txt', 'w') as f:
    for text in cleaned_texts:
        f.write(text + "\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2fcb814e5ce8> in <cell line: 17>()
#      15
#      16 # Load and split PDF pages
# ---> 17 loader = PyPDFLoader("/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf")
#      18 pages = loader.load_and_split()
#      19
#
# /usr/local/lib/python3.10/dist-packages/langchain/document_loaders/pdf.py in __init__(self, file_path, password)
#     132             )
#     133         self.parser = PyPDFParser(password=password)
# --> 134         super().__init__(file_path)
#     135
#     136     def load(self) -> List[Document]:
#
# /usr/local/lib/python3.10/dist-packages/langchain/document_loaders/pdf.py in __init__(self, file_path)
#      89             self.file_path = str(temp_pdf)
#      90         elif not os.path.isfile(self.file_path):
# ...

# %%
# Создание пустой строки для хранения текста
text = ''

# Проход по каждой странице и добавление ее текста в общую строку
for page in pages:
    text += str(page)

print(text)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-668f2c303a50> in <cell line: 17>()
#      17 for page in pages:
#      18     # Получение текста страницы
# ---> 19     page_text = page["page_content"]
#      20
#      21     # Очистка текста
#
# TypeError: 'Document' object is not subscriptable

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Инициализация разделителя текста
text_splitter = RecursiveCharacterTextSplitter(
    # Установка небольшого размера фрагмента
    chunk_size=100,
    chunk_overlap=20,
    length_function=len,
)


split_texts = text_splitter.split_text(text)

# Печать разделенного текста
for text in split_texts:
    print(text)
# Out:
# 'page': 497}

# %%
import re

# Функция для очистки текста от лишних символов
def clean_text(text):
    # Удаление символов препинания
    text = re.sub(r'[^\w\s]', '', text)

    # Удаление символов перевода строки
    text = re.sub(r'\n', ' ', text)

    # Удаление лишних пробелов
    text = re.sub(r'\s+', ' ', text)

    return text.strip()

# Перебор страниц PDF и очистка текста
for page in pages:
    # Получение текста страницы
    page_text = page["page_content"]

    # Очистка текста
    cleaned_text = clean_text(page_text)

    # Печать очищенного текста
    print(cleaned_text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-668f2c303a50> in <cell line: 17>()
#      17 for page in pages:
#      18     # Получение текста страницы
# ---> 19     page_text = page["page_content"]
#      20
#      21     # Очистка текста
#
# TypeError: 'Document' object is not subscriptable

# %%
# открыть файл в режиме чтения бинарных данных
with open('datasets/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf', 'rb') as file:
    reader = pypdf.PdfFileReader(file)
    text = ''
    # прочитать каждую страницу в PDF
    for page in range(reader.numPages):
        text += reader.getPage(page).extract_text()
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[4], line 3
#       1 # открыть файл в режиме чтения бинарных данных
#       2 with open('datasets/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf', 'rb') as file:
# ----> 3     reader = pypdf.PdfFileReader(file)
#       4     text = ''
#       5     # прочитать каждую страницу в PDF
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdf\_reader.py:2297, in PdfFileReader.__init__(self, *args, **kwargs)
#    2296 def __init__(self, *args: Any, **kwargs: Any) -> None:
# -> 2297     deprecation_with_replacement("PdfFileReader", "PdfReader", "3.0.0")
#    2298     if "strict" not in kwargs and len(args) < 2:
#    2299         kwargs["strict"] = True  # maintain the default
#
# ...

# %%
# предобработка текста
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(text)
filtered_text = [word for word in word_tokens if word.casefold() not in stop_words]
ps = PorterStemmer()
stemmed_text = [ps.stem(word) for word in filtered_text]

print(stemmed_text)

# %%
# !pip install pypdf pypdf2

# %%
import os
import openai
import sys
OPENAI_API_KEY='Bearer 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'

# %%
from langchain.document_loaders import PyPDFLoader

# Замените 'your_file.pdf' на путь к вашему PDF-файлу
loader = PyPDFLoader("datasets/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf")
pages = loader.load()

all_page_text=[p.page_content for p in pages]
joined_page_text=" ".join(all_page_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\document_loaders\pdf.py:128, in PyPDFLoader.__init__(self, file_path, password)
#     127 try:
# --> 128     import pypdf  # noqa:F401
#     129 except ImportError:
#
# ModuleNotFoundError: No module named 'pypdf'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 4
#       1 from langchain.document_loaders import PyPDFLoader
#       3 # Замените 'your_file.pdf' на путь к вашему PDF-файлу
# ----> 4 loader = PyPDFLoader("datasets/Sovremenny_skraping_veb-saytov_s_pomoschyu_Python_2021_Rayan_Mitchell.pdf")
#       5 pages = loader.load()
#       7 all_page_text=[p.page_content for p in pages]
#
# ...
