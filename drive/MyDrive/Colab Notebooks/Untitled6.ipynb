# %%
# !pip install BeautifulSoup4
# !pip install captcha-solver
# !pip install selenium
# !pip install requests
# !pip install fs
# Out:
# ERROR: Invalid requirement: '—upgrade'
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for captcha-solver: filename=captcha_solver-0.1.5-py3-none-any.whl size=7828 sha256=eec5c6a9fd76f223e9de4c94d8a5a5eb80887fdaae94a25d289475c533e7aea2
#   Stored in directory: /root/.cache/pip/wheels/74/31/d4/9413bff91774730bd953685492aa4e45a79ac28226805ca6ef
# Successfully built captcha-solver
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 3.3 MB/s eta 0:00:00
# ...

# %%
import subprocess

command = 'curl -O "https://kinescope.io/22f10966-2052-41cd-b702-f3fdd9057b45/master.m3u8?expires=1691308"'

subprocess.run(command, shell=True)
# Out:
# CompletedProcess(args='curl -O "https://kinescope.io/22f10966-2052-41cd-b702-f3fdd9057b45/master.m3u8?expires=1691308"', returncode=0)

# %%
# !ffmpeg -allowed_extensions ALL -i master.m3u8 -c copy output.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !ffmpeg -protocol_whitelist file,https,tls,crypto,data -i "https://kinescope.io/22f10966-2052-41cd-b702-f3fdd9057b45/master.m3u8?expires=1691308" -c copy output.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
