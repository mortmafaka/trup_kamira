# %%
import requests
import json
import smtplib
from email.message import EmailMessage

# Замените на свой адрес электронной почты и пароль
email_address = "queuelaqueue@gmail.com"
email_password = "YnB-mc5-N72-m6P"

def get_new_records():
    url = 'https://my.npbfx.com/mobile/billing/rest/payments/list'

    headers = {
        'authority': 'my.npbfx.com',
        'accept': '*/*',
        'accept-language': 'ru,en;q=0.9',
        'referer': 'https://my.npbfx.com/billing/history',

        'Authorization': 'Bearer GpsvAHoASG6afnb4qigClzV7DgQ'
    }

    response = requests.get(url, headers=headers)
    data = json.loads(response.text)
    return data

def send_email_notification(new_records):
    msg = EmailMessage()
    msg.set_content(f'Найдены новые записи: {new_records}')

    msg['Subject'] = 'Новые записи в истории оплат'
    msg['From'] = email_address
    msg['To'] = 'mortmafaka@gmail.com'

    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.login(email_address, email_password)
    server.send_message(msg)
    server.quit()

def main():
    previous_records = get_new_records()

    while True:
        current_records = get_new_records()

        new_records = [record for record in current_records if record not in previous_records]

        if new_records:
            send_email_notification(new_records)
            previous_records = current_records

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c4864671f19d> in <cell line: 51>()
#      50
#      51 if __name__ == "__main__":
# ---> 52     main()
#
# <ipython-input-1-c4864671f19d> in main()
#      41
#      42     while True:
# ---> 43         current_records = get_new_records()
#      44
#      45         new_records = [record for record in current_records if record not in previous_records]
#
# <ipython-input-1-c4864671f19d> in get_new_records()
#      20     }
#      21
# ---> 22     response = requests.get(url, headers=headers)
#      23     data = json.loads(response.text)
#      24     return data
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ...

# %%
import requests
import json

def get_records():
    url = 'https://my.npbfx.com/mobile/billing/rest/payments/list'

    headers = {
        'accept': '*/*',
        'accept-language': 'ru,en;q=0.9',
        'referer': 'https://my.npbfx.com/billing/history',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 YaBrowser/23.3.0.2246 Yowser/2.5 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest',
        'Authorization': 'Bearer GpsvAHoASG6afnb4qigClzV7DgQ'
    }

    response = requests.get(url, headers=headers)
    data = json.loads(response.text)
    return data

records = get_records()
print(records)
import requests

# Замените 'your_ifttt_key' на ваш ключ IFTTT, который вы можете найти на странице https://ifttt.com/maker_webhooks
ifttt_key = 'bVyMiUoNf5zSVZTMlPrk5z2lzRxoj53M3FIXYOHclrQ'

# Замените 'new_record' на имя вашего триггера
event_name = 'new_record'

# Отправка запроса Webhook-а для вызова сценария IFTTT
url = f'https://maker.ifttt.com/trigger/{event_name}/with/key/{ifttt_key}'
response = requests.post(url)

if response.status_code == 200:
    print("Уведомление успешно отправлено.")
else:
    print(f"Ошибка при отправке уведомления: {response.status_code}")
# Out:
# {'resultCode': 'OK', 'comment': '', 'param1': '', 'obj': {'list': [{'id': 707039, 'tradeAccountNumberFrom': 189101, 'productName': 'contract_type_cpa_rub', 'currencyFrom': 'RUB', 'amountFrom': 10000, 'registered': 1646223876525, 'processed': 1646223882639, 'type': 'INCOMING', 'methodPlaceholder': 'internal_transfer', 'status': 'PROCESSED'}, {'id': 707052, 'tradeAccountNumberFrom': 189101, 'productName': 'contract_type_cpa_rub', 'currencyFrom': 'RUB', 'amountFrom': 45000.0, 'registered': 1646224637457, 'processed': 1646304419453, 'type': 'OUTGOING', 'methodPlaceholder': 'moneta_plastic_payout__capitalist', 'status': 'PROCESSED'}, {'id': 683931, 'tradeAccountNumberFrom': 189101, 'productName': 'contract_type_cpa_rub', 'currencyFrom': 'RUB', 'amountFrom': 62730.0, 'registered': 1640006435445, 'processed': 1640007341637, 'type': 'OUTGOING', 'methodPlaceholder': 'moneta_plastic_payout__capitalist', 'status': 'PROCESSED'}, {'id': 683927, 'tradeAccountNumberFrom': 189101, 'productName': 'co
# ...

# %%
import requests
import json
import time

def get_records():
    url = 'https://my.npbfx.com/mobile/billing/rest/payments/list'

    headers = {
        'accept': '*/*',
        'accept-language': 'ru,en;q=0.9',
        'referer': 'https://my.npbfx.com/billing/history',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 YaBrowser/23.3.0.2246 Yowser/2.5 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest',
        'Authorization': 'Bearer GpsvAHoASG6afnb4qigClzV7DgQ'
    }

    response = requests.get(url, headers=headers)
    data = json.loads(response.text)
    return data

def send_ifttt_notification():
    event_name = 'new_record'
    url = f'https://maker.ifttt.com/trigger/{event_name}/with/key/{ifttt_key}'
    response = requests.post(url)

    if response.status_code == 200:
        print("Уведомление успешно отправлено.")
    else:
        print(f"Ошибка при отправке уведомления: {response.status_code}")

last_records = get_records()

while True:
    time.sleep(60)
    new_records = get_records()
    new_records_found = False

    for new_record in new_records['obj']['list']:
        if new_record not in last_records['obj']['list']:
            print(f"Новая запись: {new_record}")
            send_ifttt_notification()
            new_records_found = True

    if not new_records_found:
        print("Изменений нет.")

    last_records = new_records
# Out:
# Новая запись: {'id': 891461, 'tradeAccountNumberFrom': 189101, 'productName': 'contract_type_cpa_rub', 'currencyFrom': 'RUB', 'amountFrom': 10000.0, 'registered': 1686820457917, 'type': 'OUTGOING', 'methodPlaceholder': 'advcash_usdt_payout__trc20_v2', 'status': 'NEW'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1213adc61127> in <cell line: 33>()
#      39         if new_record not in last_records['obj']['list']:
#      40             print(f"Новая запись: {new_record}")
# ---> 41             send_ifttt_notification()
#      42             new_records_found = True
#      43
#
# <ipython-input-3-1213adc61127> in send_ifttt_notification()
#      21 def send_ifttt_notification():
#      22     event_name = 'new_record'
# ---> 23     url = f'https://maker.ifttt.com/trigger/{event_name}/with/key/{ifttt_key}'
#      24     response = requests.post(url)
# ...
