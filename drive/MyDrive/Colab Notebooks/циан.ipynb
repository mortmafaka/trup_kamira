# %%
rawdata ={  "count": 6,
  "newbuildings": [
    {
      "address": "Челябинск, просп. Ленина",
      "url": "https://chelyabinsk.cian.ru/zhiloy-kompleks-4-lenina-chelyabinsk-4001568/",
      "id": 4001568,
      "displayName": "ЖК «4 Ленина»",
      "imageUrl": "https://cdn-p.cian.site/images/37/612/231/4-lenina-chelyabinsk-jk-1322167351-6.jpg",
      "statusDisplay": "Сдача в 2023—2024",
      "name": "4 Ленина",
      "undergroundInfo": None,
      "developerLogoUrl": "/CompanyImg.axd?id=10640&rnd=983891"
    },
    {
      "address": "Челябинск, Лесопарковая ул.",
      "url": "https://chelyabinsk.cian.ru/zhiloy-kompleks-lesoparkovyy-chelyabinsk-20932/",
      "id": 20932,
      "displayName": "ЖК «Лесопарковый»",
      "imageUrl": "https://cdn-p.cian.site/images/21/780/121/lesoparkovyy-chelyabinsk-jk-1210871258-6.jpg",
      "statusDisplay": "Сдача в 4 кв. 2024, есть сданные",
      "name": "Лесопарковый",
      "undergroundInfo": None,
      "developerLogoUrl": "/CompanyImg.axd?id=17335&rnd=22543"
    },
    {
      "address": "Челябинск, ул. Энгельса",
      "url": "https://chelyabinsk.cian.ru/zhiloy-kompleks-zapadnyy-luch-chelyabinsk-31226/",
      "id": 31226,
      "displayName": "ЖК «Западный луч»",
      "imageUrl": "https://cdn-p.cian.site/images/80/129/101/zapadnyy-luch-chelyabinsk-jk-1019210873-6.jpg",
      "statusDisplay": "Сдача в 2023—2024, есть сданные",
      "name": "Западный луч",
      "undergroundInfo": None,
      "developerLogoUrl": "/CompanyImg.axd?id=10677&rnd=80031"
    },
    {
      "address": "Челябинск, ул. Героя России А.В. Яковлева",
      "url": "https://chelyabinsk.cian.ru/zhiloy-kompleks-manhetten-chelyabinsk-31021/",
      "id": 31021,
      "displayName": "ЖК «Манхэттен»",
      "imageUrl": "https://cdn-p.cian.site/images/90/956/831/manhetten-chelyabinsk-jk-1386590973-6.jpg",
      "statusDisplay": "Сдача в 2023—2026, есть сданные",
      "name": "Манхэттен",
      "undergroundInfo": None,
      "developerLogoUrl": "/CompanyImg.axd?id=10649&rnd=366536"
    },
    {
      "address": "Челябинск, Лесопарковая ул.",
      "url": "https://chelyabinsk.cian.ru/zhiloy-kompleks-gagarin-residence-chelyabinsk-31664/",
      "id": 31664,
      "displayName": "ЖК «Gagarin Residence (Гагарин Резиденс)»",
      "imageUrl": "https://cdn-p.cian.site/images/7/032/212/gagarin-residence-gagarin-rezidens-chelyabinsk-jk-212230789-6.jpg",
      "statusDisplay": "Сдан",
      "name": "Gagarin Residence (Гагарин Резиденс)",
      "undergroundInfo": None,
      "developerLogoUrl": "/CompanyImg.axd?id=10712&rnd=594655"
    },
    {
      "address": "Челябинск, ул. Труда",
      "url": "https://chelyabinsk.cian.ru/zhiloy-kompleks-apartamenty-golos-v-serdce-goroda-chelyabinsk-3859981/",
      "id": 3859981,
      "displayName": "ЖК «Апартаменты ГОЛОС в сердце города»",
      "imageUrl": "https://cdn-p.cian.site/images/31/973/941/apartamenty-golos-v-serdce-goroda-chelyabinsk-jk-1493791382-6.jpg",
      "statusDisplay": "Сдача в 4 кв. 2025",
      "name": "Апартаменты ГОЛОС в сердце города",
      "undergroundInfo": None,
      "developerLogoUrl": "/CompanyImg.axd?id=10640&rnd=724513"
    }
  ]
}

# %%
import pandas as pd



# Извлечение списка словарей с информацией о новостройках
newbuildings_data = rawdata["newbuildings"]

# Создание DataFrame из списка словарей
df = pd.DataFrame(newbuildings_data)

# Вывод содержимого DataFrame
print(df)
df.info()
# Out:
#                                      address  \
# 0                   Челябинск, просп. Ленина
# 1                Челябинск, Лесопарковая ул.
# 2                    Челябинск, ул. Энгельса
# 3  Челябинск, ул. Героя России А.В. Яковлева
# 4                Челябинск, Лесопарковая ул.
# 5                       Челябинск, ул. Труда
#
#                                                  url       id  \
# 0  https://chelyabinsk.cian.ru/zhiloy-kompleks-4-...  4001568
# 1  https://chelyabinsk.cian.ru/zhiloy-kompleks-le...    20932
# 2  https://chelyabinsk.cian.ru/zhiloy-kompleks-za...    31226
# 3  https://chelyabinsk.cian.ru/zhiloy-kompleks-ma...    31021
# 4  https://chelyabinsk.cian.ru/zhiloy-kompleks-ga...    31664
# 5  https://chelyabinsk.cian.ru/zhiloy-kompleks-ap...  3859981
#
#                                  displayName  \
# 0                              ЖК «4 Ленина»
# 1                          ЖК «Лесопарковый»
# 2                          ЖК «Западный луч»
# ...
