# %%
import pandas as pd

# %%
file_path = 'Notes_today 1 day ago_2019_12_01.xlsx'
df = pd.read_excel(file_path,sheet_name='data')
df.info()
display(df.describe())
display(df.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418756 entries, 0 to 418755
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Дата         418756 non-null  datetime64[ns]
#  1   Интервал     418756 non-null  datetime64[ns]
#  2   Регион       418703 non-null  object
#  3   Макрорегион  418703 non-null  object
#  4   КЦ           418385 non-null  object
#  5   Альянс       418385 non-null  object
#  6   Количество   418756 non-null  int64
#  7   note1st      418756 non-null  object
#  8   note2nd      398004 non-null  object
#  9   note3rd      92330 non-null   object
#  10  note4th      10 non-null      object
# dtypes: datetime64[ns](2), int64(1), object(8)
# memory usage: 35.1+ MB
#           Количество
# count  418756.000000
# mean        1.651695
# std         2.055430
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       199.000000
# ...

# %%
result = df.groupby(['Макрорегион', 'Регион', 'Интервал'])[['note1st', 'note2nd', 'note3rd']].count().reset_index()
display(result.hist())
# Out:
# array([[<Axes: title={'center': 'Интервал'}>,
#         <Axes: title={'center': 'note1st'}>],
#        [<Axes: title={'center': 'note2nd'}>,
#         <Axes: title={'center': 'note3rd'}>]], dtype=object)
