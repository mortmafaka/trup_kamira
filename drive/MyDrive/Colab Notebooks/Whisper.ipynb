# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-4otya9oz
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-4otya9oz
#   Resolved https://github.com/openai/whisper.git to commit 0a60fcaa9b86748389a656aa013c416030287d47
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 31.2 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230918-py3-none-any.whl size=798399 sha256=ce57d7c32dba666a4018b5ceb394d52f5a6740e846dcb3e9c4e3a33979e55c53
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vcxpvdot/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# ...

# %%
# !whisper "/content/release_notes_discuz.ogg" --model large-v2
# Out:
# 100%|█████████████████████████████████████| 2.87G/2.87G [01:00<00:00, 51.2MiB/s]
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Russian
# [00:00.000 --> 00:16.760]  По релизу посвятить, так скажем, те, которые прямо
# [00:16.760 --> 00:25.760]  видны, обратить внимание, в частности, бизнес, админа,
# [00:25.760 --> 00:29.560]  при релизе, кто занимается, да. Ну вот здесь ты можешь
# [00:29.560 --> 00:32.760]  посмотреть, вот я сейчас приехал в конфлюенс из
# [00:32.760 --> 00:40.560]  этого, из деклаба. Тут, значит, есть какая-то стандартная
# [00:40.560 --> 00:48.560]  структура уже, да, задачи о том, там, изменение базы
# [00:48.560 --> 00:53.560]  данных, изменение пермишенов по происхолдерам, да. То
# [00:53.560 --> 00:56.360]  есть, чтобы, когда, типа, мы там релизим, было понятно,
# [00:56.360 --> 00:59.360]  что вот там, например, есть права, там надо добавить-убавить,
# ...

# %%
# !whisper "/content/planer2_04.08.ogg" --model large-v2
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Russian
# [00:00.000 --> 00:09.000]  Да, окей, ну мы тогда там, получается, поизучаем, да, еще вопрос реализации, да, про которую Саша говорит.
# [00:09.000 --> 00:14.000]  Ну и как бы, чтобы как-то окончательно делать, да, надо будет тогда вот...
# [00:14.000 --> 00:16.000]  По индикативу понять.
# [00:16.000 --> 00:19.000]  Ну, по индикативу понять, да, там, и...
# [00:19.000 --> 00:28.000]  Вот этот вопрос, который Саша поднял, что оставить только один режим, я думаю, тут, наверное, вряд ли, да, ну, к этому мы придем.
# [00:29.000 --> 00:30.000]  Оба, да.
# [00:30.000 --> 00:42.000]  Вот, поэтому вопрос, наверное, остается про индикатив такой, да, существенный, вот, тоже как бы надо будет, ну, прояснить на этот счет.
# [00:44.000 --> 00:45.000]  Так.
# ...

# %%
# !whisper "/content/planer3_04.08.ogg" --model large-v2
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Russian
# [00:00.000 --> 00:07.000]  Продакшн CRM
# [00:30.000 --> 00:40.000]  Продакшн CRM
# [01:00.000 --> 01:10.000]  Продакшн CRM
# [01:10.000 --> 01:20.000]  Продакшн CRM
# [01:40.000 --> 01:50.000]  Продакшн CRM
# [01:50.000 --> 02:10.000]  Продакшн CRM
# [02:10.000 --> 02:20.000]  Продакшн CRM
# [02:20.000 --> 02:30.000]  Продакшн CRM
# [02:30.000 --> 02:40.000]  Продакшн CRM
# [02:40.000 --> 02:50.000]  Продакшн CRM
# [02:50.000 --> 03:10.000]  Продакшн CRM
# [03:10.000 --> 03:20.000]  Продакшн CRM
# [03:20.000 --> 03:40.000]  Продакшн CRM
# [03:40.000 --> 03:50.000]  Продакшн CRM
# [03:50.000 --> 04:10.000]  Продакшн CRM
# [04:10.000 --> 04:20.000]  Продакшн CRM
# [04:20.000 --> 04:40.000]  Продакшн CRM
# [04:40.000 --> 05:00.000]  Продакшн CRM
# [05:00.000 --> 05:10.000]  Продакшн CRM
# [05:10.000 --> 05:30.000]  Продакшн CRM
# ...
