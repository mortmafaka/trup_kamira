# %%
import numpy as np

# Вычисление логарифма числа
x = 1000
log_x = np.log10(x)
print(log_x)  # Результат: 3.0

# Вычисление логарифма для массива чисел
arr = np.array([1, 10, 100, 1000])
log_arr = np.log10(arr)
print(log_arr)  # Результат: [0. 1. 2. 3.]
# Out:
# 3.0
# [0. 1. 2. 3.]
